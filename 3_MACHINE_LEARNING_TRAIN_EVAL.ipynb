# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronc09/peds_lupus_flare_prediction_ML_gene-expression/blob/main/3_MACHINE_LEARNING_TRAIN_EVAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pickle
import pandas as pd

drive_path = '/content/drive/MyDrive/lupus_final_df.pkl'
lupus_final_df = pd.read_pickle(drive_path)

extracted_cols_path = '/content/drive/MyDrive/features_selected.pkl'
with open(extracted_cols_path, 'rb') as f:
  features_selected = list(pickle.load(f))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 440 total samples from lupus office visits- 367 are non-pre-flare and 73 are pre-flare
lupus_final_df["preflare_bool"].value_counts()
# Out:
# preflare_bool
# False    367
# True      73
# Name: count, dtype: int64

# %%
# Number of gene-expressions selected from the feature-selection process
len(features_selected)
# Out:
# 1979

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix, ConfusionMatrixDisplay, f1_score, average_precision_score, roc_auc_score, matthews_corrcoef
import random
import matplotlib.pyplot as plt
import shutil
import os

# %%
# y= binary target outcome data- "True" for pre-flare and "False" for non-pre-flare, that will be used to train ML models to predict
# X= input data with feature-selected gene-expressions that will be used to train/ test ML models to predict the target outcome
y = lupus_final_df["preflare_bool"]
X = lupus_final_df[features_selected]

# Setting up hyperparameter sets for gridsearch
param_grids = {
    "KNN": {
        "n_neighbors": [3, 5, 7, 11],
        "weights": ["uniform", "distance"],
    },
    "LogisticRegression": {
        "C": [0.001, 0.01, 0.1, 1, 10],
        "penalty": ["l1", "l2"],
        "solver": ["liblinear"],
        "class_weight": [None, "balanced"]
    },
    "SVM_linear": {
        "C": [0.1, 1, 10],
        "kernel": ["linear"],
        "class_weight": [None, "balanced"]
    },
    "SVM": {
        "C": [0.1, 1, 10, 20],
        "gamma": ["scale", "auto"],
        "kernel": ["rbf"],
        "class_weight": [None, "balanced"]
    },
    "GaussianNB": {
         "var_smoothing": [1e-06, 1e-05, 1e-04, 1e-03, 1e-02, 1e-01],
    },
    "RandomForest": {
        "max_depth": [None, 5, 10, 20],
        "min_samples_split": [2, 5, 10],
        "n_estimators": [50, 100, 200],
        "class_weight": [None, "balanced", "balanced_subsample"]
    },
    "XGBoost": {
        "learning_rate": [0.1, 0.3, 0.5],
        "max_depth": [1, 3, 6],
        "n_estimators": [100, 200, 500, 700],
    },
    "NeuralNet": {
        "hidden_layer_sizes": [(50,), (100,), (200,), (50, 50)],
        "activation": ["relu", "tanh"],
        "alpha": [0.0001, 0.001, 0.01],
    },
}

# Create new lists to store results from all 5 random seed runs
all_results = []
all_confusion_matrices = []

# Set up different random seeds to run 5 times
random.seed(42)
SEEDS = random.sample(range(1, 10000), 5)
for seed in SEEDS:
  print(f"\nRunning experiments with random seed: {seed}")

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed, stratify=y)

  results = {}
  for model_name, param_grid in param_grids.items():
      print(f"Running GridSearchCV for {model_name}...")

      if model_name == "KNN":
          base_model = KNeighborsClassifier()
      elif model_name == "LogisticRegression":
          base_model = LogisticRegression(random_state=seed, max_iter=1000)
      elif model_name == "SVM_linear":
          base_model = SVC(random_state=seed, probability=True)
      elif model_name == "SVM":
          base_model = SVC(random_state=seed, probability=True)
      elif model_name == "GaussianNB":
          base_model = GaussianNB()
      elif model_name == "RandomForest":
          base_model = RandomForestClassifier(random_state=seed)
      elif model_name == "XGBoost":
          base_model = XGBClassifier(random_state=seed, eval_metric='logloss')
      elif model_name == "NeuralNet":
          base_model = MLPClassifier(random_state=seed, max_iter=1000)

      # Exclude tree-based models from scaling data
      if model_name in ["RandomForest", "XGBoost"]:
          pipe = Pipeline([
                ("model", base_model)
          ])
      else:
          pipe = Pipeline([
                ("scaler", StandardScaler()),
                ("model", base_model)
          ])

      param_grid_pipe = {f"model__{k}": v for k, v in param_grid.items()}

      # Set up Stratified 5-fold training/test data splits
      cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

      # Use the pipeline and parameter grid for GridSearchCV
      grid_search = GridSearchCV(pipe, param_grid_pipe, cv=cv, scoring='f1', n_jobs=-1)

      # Fit training data to GridSearchCV
      grid_search.fit(X_train, y_train)

      best_model = grid_search.best_estimator_

      # Make predictions on the test data using the best model paramters
      y_pred = best_model.predict(X_test)

      # Obtain predict_proba probability for later metric use
      y_pred_proba = best_model.predict_proba(X_test)[:, 1] if hasattr(best_model, "predict_proba") else None

      # Setting up for metric evaluations
      accuracy = accuracy_score(y_test, y_pred)
      precision = precision_score(y_test, y_pred, zero_division=0)
      recall = recall_score(y_test, y_pred)
      f1 = f1_score(y_test, y_pred)
      roc_auc = roc_auc_score(y_test, y_pred_proba) if y_pred_proba is not None else 'N/A'
      pr_auc = average_precision_score(y_test, y_pred_proba) if y_pred_proba is not None else 'N/A'
      mcc = matthews_corrcoef(y_test, y_pred)
      confusion_mat = confusion_matrix(y_test, y_pred)

      results[model_name] = {
          "best_params": grid_search.best_params_,
          "best_score": grid_search.best_score_,
          "f1_score": f1,
          "recall": recall,
          "precision": precision,
          "accuracy": accuracy,
          "roc_auc": roc_auc,
          "pr_auc": pr_auc,
          "mcc": mcc,
          "confusion_matrix": confusion_mat,
      }

      # Add results for the current model and seed to "all_results" list
      all_results.append({
          "model": model_name,
          "f1": f1,
          "recall": recall,
          "precision": precision,
          "accuracy": accuracy,
          "roc_auc": roc_auc if roc_auc != "N/A" else None,
          "pr_auc": pr_auc if pr_auc != "N/A" else None,
          "mcc": mcc
      })

      # Store Confusion Matrix displays
      cm_display = ConfusionMatrixDisplay(confusion_matrix=confusion_mat, display_labels=[0, 1])
      all_confusion_matrices.append((f"{model_name} (Seed {seed})", cm_display))

      # Print all results
      print(f"Results for {model_name}, train/test split seed {seed}:")
      print("   " f"Best parameters: {results[model_name]['best_params']}")
      print("   " f"Best cross-validation F1-score: {results[model_name]['best_score']:.2f}")
      print("\nPerformance Metrics on the Test Dataset:")
      print("   " f"F1 Score: {results[model_name]['f1_score']:.2f}")
      print("   " f"Recall: {results[model_name]['recall']:.1%}")
      print("   " f"Precision: {results[model_name]['precision']:.1%}")
      print("   " f"Accuracy: {results[model_name]['accuracy']:.1%}")
      if isinstance(results[model_name]['pr_auc'], (int, float)):
          print("   " f"PR-AUC: {results[model_name]['pr_auc']:.2f}")
      else:
          print("   " f"PR-AUC: {results[model_name]['pr_auc']}")
      if isinstance(results[model_name]['roc_auc'], (int, float)):
          print("   " f"ROC-AUC: {results[model_name]['roc_auc']:.2f}")
      else:
          print("   " f"ROC-AUC: {results[model_name]['roc_auc']}")
      print("   " f"MCC: {results[model_name]['mcc']:.2f}")

      print("-" * 60)
# Out:
# Running experiments with random seed: 1825
# Running GridSearchCV for KNN...
# Results for KNN, train/test split seed 1825:
#    Best parameters: {'model__n_neighbors': 3, 'model__weights': 'uniform'}
#    Best cross-validation F1-score: 0.09
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.11
#    Recall: 6.7%
#    Precision: 25.0%
#    Accuracy: 80.7%
#    PR-AUC: 0.19
#    ROC-AUC: 0.54
#    MCC: 0.05
# ------------------------------------------------------------
# Running GridSearchCV for LogisticRegression...
# Results for LogisticRegression, train/test split seed 1825:
#    Best parameters: {'model__C': 10, 'model__class_weight': 'balanced', 'model__penalty': 'l2', 'model__solver': 'liblinear'}
#    Best cross-validation F1-score: 0.54
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.61
#    Recall: 66.7%
#    Precision: 55.6%
#    Accuracy: 85.2%
#    PR-AUC: 0.78
#    ROC-AUC: 0.92
#    MCC: 0.52
# ------------------------------------------------------------
# Running GridSearchCV for SVM_linear...
# Results for SVM_linear, train/test split seed 1825:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': None, 'model__kernel': 'linear'}
#    Best cross-validation F1-score: 0.46
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.48
#    Recall: 33.3%
#    Precision: 83.3%
#    Accuracy: 87.5%
#    PR-AUC: 0.62
#    ROC-AUC: 0.88
#    MCC: 0.48
# ------------------------------------------------------------
# Running GridSearchCV for SVM...
# Results for SVM, train/test split seed 1825:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': 'balanced', 'model__gamma': 'scale', 'model__kernel': 'rbf'}
#    Best cross-validation F1-score: 0.17
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.16
#    ROC-AUC: 0.37
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for GaussianNB...
# Results for GaussianNB, train/test split seed 1825:
#    Best parameters: {'model__var_smoothing': 0.1}
#    Best cross-validation F1-score: 0.48
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.49
#    Recall: 73.3%
#    Precision: 36.7%
#    Accuracy: 73.9%
#    PR-AUC: 0.33
#    ROC-AUC: 0.73
#    MCC: 0.38
# ------------------------------------------------------------
# Running GridSearchCV for RandomForest...
# Results for RandomForest, train/test split seed 1825:
#    Best parameters: {'model__class_weight': None, 'model__max_depth': None, 'model__min_samples_split': 2, 'model__n_estimators': 50}
#    Best cross-validation F1-score: 0.06
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.35
#    ROC-AUC: 0.50
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for XGBoost...
# Results for XGBoost, train/test split seed 1825:
#    Best parameters: {'model__learning_rate': 0.3, 'model__max_depth': 1, 'model__n_estimators': 500}
#    Best cross-validation F1-score: 0.19
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.27
#    ROC-AUC: 0.63
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for NeuralNet...
# Results for NeuralNet, train/test split seed 1825:
#    Best parameters: {'model__activation': 'relu', 'model__alpha': 0.0001, 'model__hidden_layer_sizes': (200,)}
#    Best cross-validation F1-score: 0.50
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.32
#    Recall: 20.0%
#    Precision: 75.0%
#    Accuracy: 85.2%
#    PR-AUC: 0.71
#    ROC-AUC: 0.91
#    MCC: 0.34
# ------------------------------------------------------------
#
# Running experiments with random seed: 410
# Running GridSearchCV for KNN...
# Results for KNN, train/test split seed 410:
#    Best parameters: {'model__n_neighbors': 3, 'model__weights': 'uniform'}
#    Best cross-validation F1-score: 0.13
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.10
#    Recall: 6.7%
#    Precision: 20.0%
#    Accuracy: 79.5%
#    PR-AUC: 0.19
#    ROC-AUC: 0.56
#    MCC: 0.02
# ------------------------------------------------------------
# Running GridSearchCV for LogisticRegression...
# Results for LogisticRegression, train/test split seed 410:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': 'balanced', 'model__penalty': 'l2', 'model__solver': 'liblinear'}
#    Best cross-validation F1-score: 0.56
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.63
#    Recall: 86.7%
#    Precision: 50.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.80
#    ROC-AUC: 0.95
#    MCC: 0.57
# ------------------------------------------------------------
# Running GridSearchCV for SVM_linear...
# Results for SVM_linear, train/test split seed 410:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': None, 'model__kernel': 'linear'}
#    Best cross-validation F1-score: 0.53
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.48
#    Recall: 33.3%
#    Precision: 83.3%
#    Accuracy: 87.5%
#    PR-AUC: 0.84
#    ROC-AUC: 0.96
#    MCC: 0.48
# ------------------------------------------------------------
# Running GridSearchCV for SVM...
# Results for SVM, train/test split seed 410:
#    Best parameters: {'model__C': 1, 'model__class_weight': 'balanced', 'model__gamma': 'scale', 'model__kernel': 'rbf'}
#    Best cross-validation F1-score: 0.17
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.33
#    Recall: 20.0%
#    Precision: 100.0%
#    Accuracy: 86.4%
#    PR-AUC: 0.62
#    ROC-AUC: 0.84
#    MCC: 0.41
# ------------------------------------------------------------
# Running GridSearchCV for GaussianNB...
# Results for GaussianNB, train/test split seed 410:
#    Best parameters: {'model__var_smoothing': 0.1}
#    Best cross-validation F1-score: 0.51
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.51
#    Recall: 93.3%
#    Precision: 35.0%
#    Accuracy: 69.3%
#    PR-AUC: 0.40
#    ROC-AUC: 0.82
#    MCC: 0.44
# ------------------------------------------------------------
# Running GridSearchCV for RandomForest...
# Results for RandomForest, train/test split seed 410:
#    Best parameters: {'model__class_weight': None, 'model__max_depth': None, 'model__min_samples_split': 2, 'model__n_estimators': 50}
#    Best cross-validation F1-score: 0.06
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 81.8%
#    PR-AUC: 0.19
#    ROC-AUC: 0.50
#    MCC: -0.05
# ------------------------------------------------------------
# Running GridSearchCV for XGBoost...
# Results for XGBoost, train/test split seed 410:
#    Best parameters: {'model__learning_rate': 0.5, 'model__max_depth': 3, 'model__n_estimators': 100}
#    Best cross-validation F1-score: 0.22
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.21
#    Recall: 13.3%
#    Precision: 50.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.27
#    ROC-AUC: 0.64
#    MCC: 0.19
# ------------------------------------------------------------
# Running GridSearchCV for NeuralNet...
# Results for NeuralNet, train/test split seed 410:
#    Best parameters: {'model__activation': 'relu', 'model__alpha': 0.01, 'model__hidden_layer_sizes': (200,)}
#    Best cross-validation F1-score: 0.55
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.62
#    Recall: 60.0%
#    Precision: 64.3%
#    Accuracy: 87.5%
#    PR-AUC: 0.83
#    ROC-AUC: 0.95
#    MCC: 0.55
# ------------------------------------------------------------
#
# Running experiments with random seed: 4507
# Running GridSearchCV for KNN...
# Results for KNN, train/test split seed 4507:
#    Best parameters: {'model__n_neighbors': 7, 'model__weights': 'uniform'}
#    Best cross-validation F1-score: 0.06
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.29
#    ROC-AUC: 0.60
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for LogisticRegression...
# Results for LogisticRegression, train/test split seed 4507:
#    Best parameters: {'model__C': 10, 'model__class_weight': 'balanced', 'model__penalty': 'l2', 'model__solver': 'liblinear'}
#    Best cross-validation F1-score: 0.63
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.67
#    Recall: 80.0%
#    Precision: 57.1%
#    Accuracy: 86.4%
#    PR-AUC: 0.83
#    ROC-AUC: 0.92
#    MCC: 0.60
# ------------------------------------------------------------
# Running GridSearchCV for SVM_linear...
# Results for SVM_linear, train/test split seed 4507:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': None, 'model__kernel': 'linear'}
#    Best cross-validation F1-score: 0.44
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.67
#    Recall: 53.3%
#    Precision: 88.9%
#    Accuracy: 90.9%
#    PR-AUC: 0.78
#    ROC-AUC: 0.91
#    MCC: 0.64
# ------------------------------------------------------------
# Running GridSearchCV for SVM...
# Results for SVM, train/test split seed 4507:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': 'balanced', 'model__gamma': 'scale', 'model__kernel': 'rbf'}
#    Best cross-validation F1-score: 0.17
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.17
#    ROC-AUC: 0.28
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for GaussianNB...
# Results for GaussianNB, train/test split seed 4507:
#    Best parameters: {'model__var_smoothing': 0.1}
#    Best cross-validation F1-score: 0.47
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.50
#    Recall: 86.7%
#    Precision: 35.1%
#    Accuracy: 70.5%
#    PR-AUC: 0.38
#    ROC-AUC: 0.83
#    MCC: 0.41
# ------------------------------------------------------------
# Running GridSearchCV for RandomForest...
# Results for RandomForest, train/test split seed 4507:
#    Best parameters: {'model__class_weight': 'balanced_subsample', 'model__max_depth': 5, 'model__min_samples_split': 10, 'model__n_estimators': 100}
#    Best cross-validation F1-score: 0.06
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.49
#    ROC-AUC: 0.70
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for XGBoost...
# Results for XGBoost, train/test split seed 4507:
#    Best parameters: {'model__learning_rate': 0.3, 'model__max_depth': 1, 'model__n_estimators': 200}
#    Best cross-validation F1-score: 0.11
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.22
#    Recall: 13.3%
#    Precision: 66.7%
#    Accuracy: 84.1%
#    PR-AUC: 0.38
#    ROC-AUC: 0.76
#    MCC: 0.25
# ------------------------------------------------------------
# Running GridSearchCV for NeuralNet...
# Results for NeuralNet, train/test split seed 4507:
#    Best parameters: {'model__activation': 'relu', 'model__alpha': 0.0001, 'model__hidden_layer_sizes': (200,)}
#    Best cross-validation F1-score: 0.49
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.67
#    Recall: 53.3%
#    Precision: 88.9%
#    Accuracy: 90.9%
#    PR-AUC: 0.82
#    ROC-AUC: 0.89
#    MCC: 0.64
# ------------------------------------------------------------
#
# Running experiments with random seed: 4013
# Running GridSearchCV for KNN...
# Results for KNN, train/test split seed 4013:
#    Best parameters: {'model__n_neighbors': 3, 'model__weights': 'uniform'}
#    Best cross-validation F1-score: 0.14
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.21
#    Recall: 13.3%
#    Precision: 50.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.21
#    ROC-AUC: 0.49
#    MCC: 0.19
# ------------------------------------------------------------
# Running GridSearchCV for LogisticRegression...
# Results for LogisticRegression, train/test split seed 4013:
#    Best parameters: {'model__C': 0.01, 'model__class_weight': None, 'model__penalty': 'l2', 'model__solver': 'liblinear'}
#    Best cross-validation F1-score: 0.55
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.73
#    Recall: 100.0%
#    Precision: 57.7%
#    Accuracy: 87.5%
#    PR-AUC: 0.80
#    ROC-AUC: 0.96
#    MCC: 0.70
# ------------------------------------------------------------
# Running GridSearchCV for SVM_linear...
# Results for SVM_linear, train/test split seed 4013:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': None, 'model__kernel': 'linear'}
#    Best cross-validation F1-score: 0.47
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.57
#    Recall: 40.0%
#    Precision: 100.0%
#    Accuracy: 89.8%
#    PR-AUC: 0.82
#    ROC-AUC: 0.95
#    MCC: 0.60
# ------------------------------------------------------------
# Running GridSearchCV for SVM...
# Results for SVM, train/test split seed 4013:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': 'balanced', 'model__gamma': 'scale', 'model__kernel': 'rbf'}
#    Best cross-validation F1-score: 0.17
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.11
#    ROC-AUC: 0.20
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for GaussianNB...
# Results for GaussianNB, train/test split seed 4013:
#    Best parameters: {'model__var_smoothing': 0.1}
#    Best cross-validation F1-score: 0.51
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.51
#    Recall: 93.3%
#    Precision: 35.0%
#    Accuracy: 69.3%
#    PR-AUC: 0.39
#    ROC-AUC: 0.81
#    MCC: 0.44
# ------------------------------------------------------------
# Running GridSearchCV for RandomForest...
# Results for RandomForest, train/test split seed 4013:
#    Best parameters: {'model__class_weight': None, 'model__max_depth': None, 'model__min_samples_split': 10, 'model__n_estimators': 50}
#    Best cross-validation F1-score: 0.11
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.37
#    ROC-AUC: 0.69
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for XGBoost...
# Results for XGBoost, train/test split seed 4013:
#    Best parameters: {'model__learning_rate': 0.1, 'model__max_depth': 1, 'model__n_estimators': 700}
#    Best cross-validation F1-score: 0.16
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 79.5%
#    PR-AUC: 0.29
#    ROC-AUC: 0.66
#    MCC: -0.09
# ------------------------------------------------------------
# Running GridSearchCV for NeuralNet...
# Results for NeuralNet, train/test split seed 4013:
#    Best parameters: {'model__activation': 'relu', 'model__alpha': 0.0001, 'model__hidden_layer_sizes': (200,)}
#    Best cross-validation F1-score: 0.50
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.69
#    Recall: 60.0%
#    Precision: 81.8%
#    Accuracy: 90.9%
#    PR-AUC: 0.74
#    ROC-AUC: 0.92
#    MCC: 0.65
# ------------------------------------------------------------
#
# Running experiments with random seed: 3658
# Running GridSearchCV for KNN...
# Results for KNN, train/test split seed 3658:
#    Best parameters: {'model__n_neighbors': 5, 'model__weights': 'uniform'}
#    Best cross-validation F1-score: 0.09
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 81.8%
#    PR-AUC: 0.20
#    ROC-AUC: 0.50
#    MCC: -0.05
# ------------------------------------------------------------
# Running GridSearchCV for LogisticRegression...
# Results for LogisticRegression, train/test split seed 3658:
#    Best parameters: {'model__C': 10, 'model__class_weight': 'balanced', 'model__penalty': 'l2', 'model__solver': 'liblinear'}
#    Best cross-validation F1-score: 0.60
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.60
#    Recall: 86.7%
#    Precision: 46.4%
#    Accuracy: 80.7%
#    PR-AUC: 0.81
#    ROC-AUC: 0.90
#    MCC: 0.53
# ------------------------------------------------------------
# Running GridSearchCV for SVM_linear...
# Results for SVM_linear, train/test split seed 3658:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': None, 'model__kernel': 'linear'}
#    Best cross-validation F1-score: 0.44
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.69
#    Recall: 60.0%
#    Precision: 81.8%
#    Accuracy: 90.9%
#    PR-AUC: 0.79
#    ROC-AUC: 0.90
#    MCC: 0.65
# ------------------------------------------------------------
# Running GridSearchCV for SVM...
# Results for SVM, train/test split seed 3658:
#    Best parameters: {'model__C': 0.1, 'model__class_weight': 'balanced', 'model__gamma': 'scale', 'model__kernel': 'rbf'}
#    Best cross-validation F1-score: 0.16
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.11
#    Recall: 6.7%
#    Precision: 25.0%
#    Accuracy: 80.7%
#    PR-AUC: 0.16
#    ROC-AUC: 0.45
#    MCC: 0.05
# ------------------------------------------------------------
# Running GridSearchCV for GaussianNB...
# Results for GaussianNB, train/test split seed 3658:
#    Best parameters: {'model__var_smoothing': 0.1}
#    Best cross-validation F1-score: 0.50
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.49
#    Recall: 73.3%
#    Precision: 36.7%
#    Accuracy: 73.9%
#    PR-AUC: 0.36
#    ROC-AUC: 0.78
#    MCC: 0.38
# ------------------------------------------------------------
# Running GridSearchCV for RandomForest...
# Results for RandomForest, train/test split seed 3658:
#    Best parameters: {'model__class_weight': 'balanced_subsample', 'model__max_depth': 5, 'model__min_samples_split': 2, 'model__n_estimators': 50}
#    Best cross-validation F1-score: 0.07
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.00
#    Recall: 0.0%
#    Precision: 0.0%
#    Accuracy: 83.0%
#    PR-AUC: 0.19
#    ROC-AUC: 0.48
#    MCC: 0.00
# ------------------------------------------------------------
# Running GridSearchCV for XGBoost...
# Results for XGBoost, train/test split seed 3658:
#    Best parameters: {'model__learning_rate': 0.5, 'model__max_depth': 1, 'model__n_estimators': 200}
#    Best cross-validation F1-score: 0.18
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.24
#    Recall: 13.3%
#    Precision: 100.0%
#    Accuracy: 85.2%
#    PR-AUC: 0.38
#    ROC-AUC: 0.65
#    MCC: 0.34
# ------------------------------------------------------------
# Running GridSearchCV for NeuralNet...
# Results for NeuralNet, train/test split seed 3658:
#    Best parameters: {'model__activation': 'tanh', 'model__alpha': 0.01, 'model__hidden_layer_sizes': (50, 50)}
#    Best cross-validation F1-score: 0.53
#
# Performance Metrics on the Test Dataset:
#    F1 Score: 0.49
#    Recall: 86.7%
#    Precision: 34.2%
#    Accuracy: 69.3%
#    PR-AUC: 0.72
#    ROC-AUC: 0.87
#    MCC: 0.40
# ------------------------------------------------------------

# %% [markdown]
# ### >> Create a figure with Confusion Matrices from the first 3 random seed runs.

# %%
seeds_1_2_3 = SEEDS[0:3]

filtered_confusion_matrices = []
for title, cm_display in all_confusion_matrices:
    try:
        seed_str = title.split('(Seed ')[1].split(')')[0]
        seed = int(seed_str)
        if seed in seeds_1_2_3:
            filtered_confusion_matrices.append((title, cm_display))
    except (IndexError, ValueError):
        pass

num_filtered_models = len(filtered_confusion_matrices)

if num_filtered_models > 0:
    cols = 4
    rows = (num_filtered_models + cols - 1) // cols

    fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(cols * 5, rows * 4))

    axes = axes.flatten()

    for i, (title, cm_display) in enumerate(filtered_confusion_matrices):
        ax = axes[i]
        cm_display.plot(ax=ax, cmap='Blues')
        ax.set_title(title)

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.suptitle(f"Confusion Matrices for Seeds {', '.join(map(str, seeds_1_2_3))}", y=1.02, fontsize=16)

    save_folder = '/content/drive/MyDrive/figures/'
    output_filename = 'confusion_matrices_from_frist_3_random_seeds'
    output_path = os.path.join(save_folder, output_filename)

    os.makedirs(save_folder, exist_ok=True)

    plt.savefig(output_path)

    plt.show()
    plt.close(fig)

# %% [markdown]
# ### >> Create a figure with Confusion Matrices from the last 2 random seed runs.

# %%
seeds_4_5 = SEEDS[3:5]

filtered_confusion_matrices_4_5 = []
for title, cm_display in all_confusion_matrices:
    try:
        seed_str = title.split('(Seed ')[1].split(')')[0]
        seed = int(seed_str)
        if seed in seeds_4_5:
            filtered_confusion_matrices_4_5.append((title, cm_display))
    except (IndexError, ValueError):
        pass

num_filtered_models_4_5 = len(filtered_confusion_matrices_4_5)

if num_filtered_models_4_5 == 0:
    print(f"No confusion matrices found for seeds {seeds_4_5}. Skipping plot generation.")
else:
    cols = 4
    rows = (num_filtered_models_4_5 + cols - 1) // cols
    fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(cols * 5, rows * 4))
    axes = axes.flatten()

    for i, (title, cm_display) in enumerate(filtered_confusion_matrices_4_5):
        ax = axes[i]
        cm_display.plot(ax=ax, cmap='Blues')
        ax.set_title(title)

    for j in range(num_filtered_models_4_5, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.suptitle(f"Confusion Matrices for Seeds {', '.join(map(str, seeds_4_5))}", y=1.02, fontsize=16) # Adjusted y-position to 1.02

    save_folder = '/content/drive/MyDrive/figures/'
    output_filename = 'confusion_matrices_from_last_2_random_seeds.png'
    output_path = os.path.join(save_folder, output_filename)

    os.makedirs(save_folder, exist_ok=True)

    plt.savefig(output_path)

    plt.show()
    plt.close(fig)

# %% [markdown]
# ### >> Create a chart with average of all metric outcomes for each model across all 5 random seed runs

# %%
print("FINAL RESULTS OF STUDY:  AVERAGE RESULTS FROM ALL 5 RANDOM SEED RUNS:")

avg_results = pd.DataFrame(all_results).groupby("model").mean(numeric_only=True)

desired_order = ['KNN', 'LogisticRegression', 'SVM_linear', 'SVM', 'GaussianNB', 'RandomForest', 'XGBoost', 'NeuralNet']
avg_results_ordered = avg_results.reindex(desired_order)

display(avg_results_ordered.style.format({"f1": "{:.2f}",
                                        "recall": "{:.1%}",
                                        "precision": "{:.1%}",
                                        "accuracy": "{:.1%}",
                                        "pr_auc": "{:.2f}",
                                        "roc_auc": "{:.2f}",
                                        "mcc": "{:.2f}"}))
# Out:
# FINAL RESULTS OF STUDY:  AVERAGE RESULTS FROM ALL 5 RANDOM SEED RUNS:
# <style type="text/css">
# </style>
# <table id="T_36480" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36480_level0_col0" class="col_heading level0 col0" >f1</th>
#       <th id="T_36480_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_36480_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_36480_level0_col3" class="col_heading level0 col3" >accuracy</th>
#       <th id="T_36480_level0_col4" class="col_heading level0 col4" >roc_auc</th>
#       <th id="T_36480_level0_col5" class="col_heading level0 col5" >pr_auc</th>
#       <th id="T_36480_level0_col6" class="col_heading level0 col6" >mcc</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36480_level0_row0" class="row_heading level0 row0" >KNN</th>
#       <td id="T_36480_row0_col0" class="data row0 col0" >0.08</td>
#       <td id="T_36480_row0_col1" class="data row0 col1" >5.3%</td>
#       <td id="T_36480_row0_col2" class="data row0 col2" >19.0%</td>
#       <td id="T_36480_row0_col3" class="data row0 col3" >81.6%</td>
#       <td id="T_36480_row0_col4" class="data row0 col4" >0.54</td>
#       <td id="T_36480_row0_col5" class="data row0 col5" >0.21</td>
#       <td id="T_36480_row0_col6" class="data row0 col6" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_36480_level0_row1" class="row_heading level0 row1" >LogisticRegression</th>
#       <td id="T_36480_row1_col0" class="data row1 col0" >0.65</td>
#       <td id="T_36480_row1_col1" class="data row1 col1" >84.0%</td>
#       <td id="T_36480_row1_col2" class="data row1 col2" >53.4%</td>
#       <td id="T_36480_row1_col3" class="data row1 col3" >84.5%</td>
#       <td id="T_36480_row1_col4" class="data row1 col4" >0.93</td>
#       <td id="T_36480_row1_col5" class="data row1 col5" >0.80</td>
#       <td id="T_36480_row1_col6" class="data row1 col6" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_36480_level0_row2" class="row_heading level0 row2" >SVM_linear</th>
#       <td id="T_36480_row2_col0" class="data row2 col0" >0.58</td>
#       <td id="T_36480_row2_col1" class="data row2 col1" >44.0%</td>
#       <td id="T_36480_row2_col2" class="data row2 col2" >87.5%</td>
#       <td id="T_36480_row2_col3" class="data row2 col3" >89.3%</td>
#       <td id="T_36480_row2_col4" class="data row2 col4" >0.92</td>
#       <td id="T_36480_row2_col5" class="data row2 col5" >0.77</td>
#       <td id="T_36480_row2_col6" class="data row2 col6" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_36480_level0_row3" class="row_heading level0 row3" >SVM</th>
#       <td id="T_36480_row3_col0" class="data row3 col0" >0.09</td>
#       <td id="T_36480_row3_col1" class="data row3 col1" >5.3%</td>
#       <td id="T_36480_row3_col2" class="data row3 col2" >25.0%</td>
#       <td id="T_36480_row3_col3" class="data row3 col3" >83.2%</td>
#       <td id="T_36480_row3_col4" class="data row3 col4" >0.43</td>
#       <td id="T_36480_row3_col5" class="data row3 col5" >0.25</td>
#       <td id="T_36480_row3_col6" class="data row3 col6" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_36480_level0_row4" class="row_heading level0 row4" >GaussianNB</th>
#       <td id="T_36480_row4_col0" class="data row4 col0" >0.50</td>
#       <td id="T_36480_row4_col1" class="data row4 col1" >84.0%</td>
#       <td id="T_36480_row4_col2" class="data row4 col2" >35.7%</td>
#       <td id="T_36480_row4_col3" class="data row4 col3" >71.4%</td>
#       <td id="T_36480_row4_col4" class="data row4 col4" >0.79</td>
#       <td id="T_36480_row4_col5" class="data row4 col5" >0.37</td>
#       <td id="T_36480_row4_col6" class="data row4 col6" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_36480_level0_row5" class="row_heading level0 row5" >RandomForest</th>
#       <td id="T_36480_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_36480_row5_col1" class="data row5 col1" >0.0%</td>
#       <td id="T_36480_row5_col2" class="data row5 col2" >0.0%</td>
#       <td id="T_36480_row5_col3" class="data row5 col3" >82.7%</td>
#       <td id="T_36480_row5_col4" class="data row5 col4" >0.57</td>
#       <td id="T_36480_row5_col5" class="data row5 col5" >0.32</td>
#       <td id="T_36480_row5_col6" class="data row5 col6" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_36480_level0_row6" class="row_heading level0 row6" >XGBoost</th>
#       <td id="T_36480_row6_col0" class="data row6 col0" >0.13</td>
#       <td id="T_36480_row6_col1" class="data row6 col1" >8.0%</td>
#       <td id="T_36480_row6_col2" class="data row6 col2" >43.3%</td>
#       <td id="T_36480_row6_col3" class="data row6 col3" >83.0%</td>
#       <td id="T_36480_row6_col4" class="data row6 col4" >0.67</td>
#       <td id="T_36480_row6_col5" class="data row6 col5" >0.32</td>
#       <td id="T_36480_row6_col6" class="data row6 col6" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_36480_level0_row7" class="row_heading level0 row7" >NeuralNet</th>
#       <td id="T_36480_row7_col0" class="data row7 col0" >0.56</td>
#       <td id="T_36480_row7_col1" class="data row7 col1" >56.0%</td>
#       <td id="T_36480_row7_col2" class="data row7 col2" >68.8%</td>
#       <td id="T_36480_row7_col3" class="data row7 col3" >84.8%</td>
#       <td id="T_36480_row7_col4" class="data row7 col4" >0.91</td>
#       <td id="T_36480_row7_col5" class="data row7 col5" >0.76</td>
#       <td id="T_36480_row7_col6" class="data row7 col6" >0.52</td>
#     </tr>
#   </tbody>
# </table>
